# %% [markdown]
# # <center> Shri Ramdeobaba College of Engineering and Management, Nagpur</center>
# ## <center>Department of Computer Science Engineering</center>
# ## <center>Python Programming LAB (CAP 204) (2021-2022)</center>
# ## <center>Practical - 09</center>
#
# ---

# %% [markdown]
# #### <strong>Name : </strong> <em>Shantanu Mane</em>
# #### <strong>Roll Number : </strong> <em>63 (E-4)</em>
# #### <strong>Section : </strong> <em>E (AIML)</em>
# #### <strong>Date : </strong> <em>2<sup>nd</sup> February 2022</em>

# %%
import pandas as pd
import folium
from geopy.distance import geodesic as GD
from geopy.geocoders import Nominatim

# %%
world = folium.Map(
    zoom_start=2
)

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6c082536c64c4e39816b9cab47a71ca0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6c082536c64c4e39816b9cab47a71ca0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6c082536c64c4e39816b9cab47a71ca0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6c082536c64c4e39816b9cab47a71ca0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
loc1 = str(input("Enter a place : "))

geoLocator = Nominatim(user_agent="my_request")
location1 = geoLocator.geocode(loc1)

print(f"Place searched : \n{location1.address}\nCoordinates : \n{location1.latitude, location1.longitude}")

loc2 = str(input("Enter a place : "))
location2 = geoLocator.geocode(loc2)

print(f"Place searched : \n{location2.address}\nCoordinates : \n{location2.latitude, location2.longitude}")

print(f"\nDistance between New York {location1.address} and Texas {location2.address} is : {GD((location1.latitude, location1.longitude),(location2.latitude, location2.longitude)).km} kms")

world = folium.Map(
    zoom_start=2
)

folium.Marker(
    location=(location1.latitude, location1.longitude)
).add_to(world)

folium.Marker(
    location=(location2.latitude, location2.longitude)
).add_to(world)

world
# Out:
# Place searched :
# Nagpur, Nagpur Urban Taluka, Nagpur District, Maharashtra, 440001, India
# Coordinates :
# (21.1498134, 79.0820556)
# Place searched :
# New York, United States
# Coordinates :
# (40.7127281, -74.0060152)
#
# Distance between New York Nagpur, Nagpur Urban Taluka, Nagpur District, Maharashtra, 440001, India and Texas New York, United States is : 12614.432953889827 kms
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_164e4c7dc13841b69487c6439f871405%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_164e4c7dc13841b69487c6439f871405%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_164e4c7dc13841b69487c6439f871405%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_164e4c7dc13841b69487c6439f871405%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
cities_df = pd.read_csv('../Assets/Indian-Cities.csv')

cities_df
# Out:
#     S.No         State Name             Capital             Area  \
# 0      1     Andhra Pradesh           Hyderabad   1,60,205 Sq Km
# 1      2  Arunachal Pradesh            Itanagar    83,743 sq. km
# 2      3              Assam              Dispur    78,438 sq. km
# 3      4              Bihar               Patna    94,163 sq. km
# 4      5       Chhattisgarh         Naya Raipur  1,36,034 sq. km
# 5      6                Goa              Panaji     3,702 sq. km
# 6      7            Gujarat         Gandhinagar  1,96,024 sq. km
# 7      8            Haryana          Chandigarh    44,212 sq. km
# 8      9   Himachal Pradesh              Shimla    55,673 sq. km
# 9     10          Jharkhand              Ranchi    79,714 sq. km
# 10    11          Karnataka           Bangalore  1,91,791 sq. km
# 11    12             Kerala  Thiruvananthapuram    38,863 sq. km
# 12    13     Madhya Pradesh              Bhopal  3,08,000 sq. km
# 13    14        Maharashtra              Mumbai  3,07,713 sq. km
# 14    15            Manipur              Imphal    22,327 sq. km
# 15    16          Meghalaya            Shillong    22,429 sq. km
# 16    17            Mizoram              Aizawl    21,081 sq. km
# 17    18           Nagaland              Kohima    16,579 sq. km
# 18    19             Odisha        Bhubaneshwar  1,55,707 sq. km
# 19    20             Punjab          Chandigarh    50,362 sq. km
# 20    21          Rajasthan              Jaipur  3,42,239 sq. km
# 21    22             Sikkim             Gangtok     7,096 sq. km
# 22    23         Tamil Nadu             Chennai  1,30,058 sq. km
# 23    24          Telangana           Hyderabad  112,077 Sq. Kms
# 24    25            Tripura            Agartala    10,491.69 km2
# 25    26        Uttarakhand            Gairsain    53,484 sq. km
# 26    27      Uttar Pradesh             Lucknow  2,40,928 sq. km
# 27    28        West Bengal             Kolkata    88,752 sq. km
#
#        Population State Established   Largest City  \
# 0   49.67 Million         1/10/1953  Visakhapatnam
# 1       13,82,611        20-02-1987       Itanagar
# 2     3,11,69,272        26-01-1950       Guwahati
# 3    10,38,04,637        26-01-1950          Patna
# 4     2,55,40,196         1/11/2000         Raipur
# 5       14,57,723        30-05-1987  Vasco da Gama
# 6     6,03,83,628          1/5/1960      Ahmedabad
# 7     2,53,53,081         1/11/1966      Faridabad
# 8       68,56,509        25-01-1971         Shimla
# 9     3,11,69,272        15-11-2000     Jamshedpur
# 10    6,11,30,704         1/11/1956      Bengaluru
# 11    3,33,87,677         1/11/1956     Malappuram
# 12    7,25,97,565         1/11/1956         Indore
# 13   11,23,72,972          1/5/1960         Mumbai
# 14      27,21,756        21-01-1972        manipur
# 15      29,64,007        21-01-1972       Shillong
# 16      10,91,014        20-02-1987         Aizawl
# 17      19,80,602         1/12/1963        Dimapur
# 18    4,19,47,358        26-01-1950    Bhubaneswar
# 19    2,77,04,236         1/11/1966       Ludhiana
# 20    6,86,21,012         1/11/1956         Jaipur
# 21       6,07,688        16-05-1975        Gangtok
# 22    7,21,38,958        26-01-1950          Tamil
# 23   350.04 Lakhs          2/6/2014      Hyderabad
# 24      36,71,032        21-01-1972       Agartala
# 25    1,01,16,752        26-01-1950       Dehradun
# 26   19,95,81,477         9/11/2000        Lucknow
# 27    9,13,47,736        26-01-1950        Kolkata
#
#                                             Languages
# 0                                              Telugu
# 1   Monpa, Miji, Aka, Sherdukpen, \nNyishi, Apatan...
# 2                                            Assamese
# 3                                         Hindi ,Urdu
# 4                                               Hindi
# 5   Konkani(official Language),\nMarathi, Hindi, E...
# 6                                            Gujarati
# 7                                               Hindi
# 8                                      Hindi & Pahari
# 9                                               Hindi
# 10                                            Kannada
# 11                                          Malayalam
# 12                                              Hindi
# 13                                            Marathi
# 14                                           Manipuri
# 15                            Khasi, Garo and English
# 16                                   Mizo and English
# 17              English, Hindi and 16 tribal dialects
# 18                                              Oriya
# 19                                            Punjabi
# 20                               Hindi and Rajasthani
# 21                          Lepcha, Bhutia and Nepali
# 22                                            Chennai
# 23                                       Telugu, Urdu
# 24                               Bengali and Kokborok
# 25                           Hindi, Garhwali, Kumaoni
# 26                                     Hindi and Urdu
# 27                                            Bengali

# %%
world = folium.Map()
geoLocator = Nominatim(user_agent="my_request")

# %%
for _, city in cities_df.iterrows():
    print(f"{city['Capital']}")
# Out:
# Hyderabad
# Itanagar
# Dispur
# Patna
# Naya Raipur
# Panaji
# Gandhinagar
# Chandigarh
# Shimla
# Ranchi
# Bangalore
# Thiruvananthapuram
# Bhopal
# Mumbai
# Imphal
# Shillong
# Aizawl
# Kohima
# Bhubaneshwar
# Chandigarh
# Jaipur
# Gangtok
# Chennai
# Hyderabad
# Agartala
# Gairsain
# Lucknow
# Kolkata

# %%
for _, city in cities_df.iterrows():
    location = geoLocator.geocode(city['Capital'])
    print(f"Location : {location.address}\n {location.latitude, location.longitude}")
    folium.Marker(
        location=(location.latitude, location.longitude),
        popup=location.address,
        tooltip=city.Capital
    ).add_to(world)
world
# Out:
# Location : Hyderabad, Bahadurpura mandal, Hyderabad, Telangana, 500 002, India
#  (17.360589, 78.4740613)
# Location : Itanagar, Itanagar EAC, Papum Pare, Arunachal Pradesh, 791111, India
#  (27.0979659, 93.6237291)
# Location : Dispur, Kamrup Metropolitan, Assam, India
#  (26.1513079, 91.79338049525902)
# Location : Patna, Patna Rural, Patna District, Bihar, 800001, India
#  (25.6093239, 85.1235252)
# Location : Nava Raipur Atal Nagar, Arang Tahsil, Raipur, Chhattisgarh, India
#  (21.1610268, 81.7864412)
# Location : Panaji, Tiswadi, North Goa, Goa, 403001, India
#  (15.4989946, 73.8282141)
# Location : Gandhinagar, Gandhinagar Taluka, Gandhinagar District, Gujarat, 382011, India
#  (23.2232877, 72.6492267)
# Location : Chandigarh, 160018, India
#  (30.7334421, 76.7797143)
# Location : Shimla, Shimla (urban), Shimla, Himachal Pradesh, 171001, India
#  (31.1041526, 77.1709729)
# Location : Ranchi, Kanke, Ranchi, Jharkhand, HINDPIRI, India
#  (23.3700501, 85.3250387)
# Location : Bengaluru, Bangalore North, Bangalore Urban, Karnataka, India
#  (12.9767936, 77.590082)
# Location : Thiruvananthapuram, Kerala, 695001, India
#  (8.5241122, 76.9360573)
# Location : Bhopal, Madhya Pradesh, 462001, India
#  (23.2584857, 77.401989)
# Location : Mumbai, Mumbai Metropolitan Region, Mumbai Suburban, Maharashtra, India
#  (19.0759899, 72.8773928)
# Location : Imphal, Lamphelpat, Imphal West, Manipur, 795001, India
#  (24.7991162, 93.9364419)
# Location : Shillong, Police Bazar Road, Mawkhar, Shillong, Mylliem, East Khasi Hills, Meghalaya, 793001, India
#  (25.5760446, 91.8825282)
# Location : Aizawl, Tlangnuam, Aizwal, Mizoram, 796190, India
#  (23.7435236, 92.7382905)
# Location : Kohīma, Kohima, Nagaland, 797003, India
#  (25.75, 94.166667)
# Location : Bhubaneshwar, Bhubaneswar Municipal Corporation, Bhubaneswar (M.Corp.), Khordha, Odisha, 751001, India
#  (20.2602964, 85.8394521)
# Location : Chandigarh, 160018, India
#  (30.7334421, 76.7797143)
# Location : Jaipur, Jaipur Municipal Corporation, Jaipur Tehsil, Jaipur, Rajasthan, 302001, India
#  (26.9154576, 75.8189817)
# Location : Gangtok, East Sikkim District, Sikkim, 737101, India
#  (27.329046, 88.6122673)
# Location : Chennai, Chennai District, Tamil Nadu, 600001, India
#  (13.0836939, 80.270186)
# Location : Hyderabad, Bahadurpura mandal, Hyderabad, Telangana, 500 002, India
#  (17.360589, 78.4740613)
# Location : Agartala, Mohanpur, West Tripura, Tripura, 799001, India
#  (23.8312377, 91.2823821)
# Location : Gairsain, Chamoli district, Uttarakhand, India
#  (30.075147649999998, 79.26650623506515)
# Location : Lucknow, Sadar, Lucknow, Uttar Pradesh, 226019, India
#  (26.8381, 80.9346001)
# Location : Kolkata, West Bengal, India
#  (22.5414185, 88.35769124388872)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_432d828ead0946bda7a4737239e6ada3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_432d828ead0946bda7a4737239e6ada3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_432d828ead0946bda7a4737239e6ada3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_432d828ead0946bda7a4737239e6ada3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...
