# %% [markdown]
# # <center> Shri Ramdeobaba College of Engineering and Management, Nagpur</center>
# ## <center>Department of Computer Science Engineering</center>
# ## <center>Python Programming LAB (CAP 204) (2021-2022)</center>
# ## <center>Practical - 09</center>
#
# ---

# %% [markdown]
# #### <strong>Name : </strong> <em>Shantanu Mane</em>
# #### <strong>Roll Number : </strong> <em>63 (E-4)</em>
# #### <strong>Section : </strong> <em>E (AIML)</em>
# #### <strong>Date : </strong> <em>2<sup>nd</sup> February 2022</em>

# %%
import pandas as pd
import folium
from geopy.distance import geodesic as GD
from geopy.geocoders import Nominatim

# %%
world = folium.Map(
    zoom_start=2
)

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
loc1 = str(input("Enter a place : "))

geoLocator = Nominatim(user_agent="my_request")
location1 = geoLocator.geocode(loc1)

print(f"Place searched : \n{location1.address}\nCoordinates : \n{location1.latitude, location1.longitude}")

loc2 = str(input("Enter a place : "))

geoLocator = Nominatim(user_agent="my_request")
location2 = geoLocator.geocode(loc2)

print(f"Place searched : \n{location2.address}\nCoordinates : \n{location2.latitude, location2.longitude}")

print(f"\nDistance between New York {location1.address} and Texas {location2.address} is : {GD((location1.latitude, location1.longitude),(location2.latitude, location2.longitude)).km} kms")

world = folium.Map(
    zoom_start=2
)

folium.Marker(
    location=(location1.latitude, location1.longitude)
).add_to(world)

folium.Marker(
    location=(location2.latitude, location2.longitude)
).add_to(world)

world
# Out:
# Place searched :
# Mumbai, Mumbai Metropolitan Region, Mumbai Suburban, Maharashtra, भारत / India
# Coordinates :
# (19.0759899, 72.8773928)
# Place searched :
# Nagpur Urban Taluka, Nagpur District, Maharashtra, भारत / India
# Coordinates :
# (21.1498134, 79.0820556)
#
# Distance between New York Mumbai, Mumbai Metropolitan Region, Mumbai Suburban, Maharashtra, भारत / India and Texas Nagpur Urban Taluka, Nagpur District, Maharashtra, भारत / India is : 688.1741806674945 kms
# ...

# %%
cities_df = pd.read_csv('../Assets/Indian-Cities.csv')

cities_df
# Out:
#     S.No         State Name             Capital             Area  \
# 0      1     Andhra Pradesh           Hyderabad   1,60,205 Sq Km
# 1      2  Arunachal Pradesh            Itanagar    83,743 sq. km
# 2      3              Assam              Dispur    78,438 sq. km
# 3      4              Bihar               Patna    94,163 sq. km
# 4      5       Chhattisgarh         Naya Raipur  1,36,034 sq. km
# 5      6                Goa              Panaji     3,702 sq. km
# 6      7            Gujarat         Gandhinagar  1,96,024 sq. km
# 7      8            Haryana          Chandigarh    44,212 sq. km
# 8      9   Himachal Pradesh              Shimla    55,673 sq. km
# 9     10          Jharkhand              Ranchi    79,714 sq. km
# 10    11          Karnataka           Bangalore  1,91,791 sq. km
# 11    12             Kerala  Thiruvananthapuram    38,863 sq. km
# 12    13     Madhya Pradesh              Bhopal  3,08,000 sq. km
# ...

# %%
cities_df['Capital']
# Out:
# 0              Hyderabad
# 1               Itanagar
# 2                 Dispur
# 3                  Patna
# 4            Naya Raipur
# 5                 Panaji
# 6            Gandhinagar
# 7             Chandigarh
# 8                 Shimla
# 9                 Ranchi
# 10             Bangalore
# 11    Thiruvananthapuram
# 12                Bhopal
# 13                Mumbai
# 14                Imphal
# 15              Shillong
# 16                Aizawl
# 17                Kohima
# 18          Bhubaneshwar
# 19            Chandigarh
# 20                Jaipur
# 21               Gangtok
# 22               Chennai
# 23             Hyderabad
# 24              Agartala
# 25              Gairsain
# 26               Lucknow
# 27               Kolkata
# Name: Capital, dtype: object

# %%
for _, city in cities_df.iterrows():
    geoLocator = Nominatim(user_agent="my_request")
    capital = city.Capital
    location = geoLocator.geocode(capital)
    print(capital, location.latitude, location.longitude)
# Out:
# Hyderabad 17.360589 78.4740613
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\Python39\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\Python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# C:\Python39\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
world = folium.Map()

world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for _, city in cities_df.iterrows():
    
    geoLocator = Nominatim(user_agent="my_request")
    capital = city.Capital
    location = geoLocator.geocode(capital)

    folium.Marker(
        location=(location.latitude, location.longitude)
    ).add_to(world)

world
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# C:\Python39\lib\http\client.py in getresponse(self)
#    1370             try:
# ...
